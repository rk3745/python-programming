# %% [markdown]
# ***Q:- Take a financial  dataset and perform EDA operations with all possible graphs using  Numpy,Pandas & Seaborn
# libraries.**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ***Data Loading & Inspection***

# %%
# Read file
df = pd.read_csv(r"C:\Users\pc\Downloads\Financial Dataset - 1.csv")

# %%
path = "\u202aC:\\Users\\pc\\Downloads\\Financial Dataset - 1.csv"
clean_path = path.replace("\u202a", "")
df = pd.read_csv(clean_path)

# %%
path = "C:\\Users\\pc\\Downloads\\Financial Dataset - 1.csv" 
print(repr(path))
# Out:
# 'C:\\Users\\pc\\Downloads\\Financial Dataset - 1.csv'

# %%
df
# Out:
#       country  year       uniqueid Has a Bank account Type of Location  \
# 0       Kenya  2018     uniqueid_1                Yes            Rural
# 1       Kenya  2018     uniqueid_2                 No            Rural
# 2       Kenya  2018     uniqueid_3                Yes            Urban
# 3       Kenya  2018     uniqueid_4                 No            Rural
# 4       Kenya  2018     uniqueid_5                 No            Urban
# ...       ...   ...            ...                ...              ...
# 23519  Uganda  2018  uniqueid_2113                 No            Rural
# 23520  Uganda  2018  uniqueid_2114                 No            Rural
# 23521  Uganda  2018  uniqueid_2115                 No            Rural
# 23522  Uganda  2018  uniqueid_2116                 No            Urban
# 23523  Uganda  2018  uniqueid_2117                 No            Rural
#
#       Cell Phone Access  household_size  Respondent Age gender_of_respondent  \
# ...

# %%
df.shape
# Out:
# (23524, 13)

# %%
df.head()
# Out:
#   country  year    uniqueid Has a Bank account Type of Location  \
# 0   Kenya  2018  uniqueid_1                Yes            Rural
# 1   Kenya  2018  uniqueid_2                 No            Rural
# 2   Kenya  2018  uniqueid_3                Yes            Urban
# 3   Kenya  2018  uniqueid_4                 No            Rural
# 4   Kenya  2018  uniqueid_5                 No            Urban
#
#   Cell Phone Access  household_size  Respondent Age gender_of_respondent  \
# 0               Yes             3.0            24.0               Female
# 1                No             5.0            70.0               Female
# 2               Yes             5.0            26.0                 Male
# 3               Yes             5.0            34.0               Female
# 4                No             8.0            26.0                 Male
#
#   The relathip with head           marital_status  \
# 0                 Spouse  Married/Living together
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23524 entries, 0 to 23523
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   country                 23510 non-null  object
#  1   year                    23524 non-null  int64
#  2   uniqueid                23524 non-null  object
#  3   Has a Bank account      23488 non-null  object
#  4   Type of Location        23509 non-null  object
#  5   Cell Phone Access       23513 non-null  object
#  6   household_size          23496 non-null  float64
#  7   Respondent Age          23490 non-null  float64
#  8   gender_of_respondent    23490 non-null  object
#  9   The relathip with head  23520 non-null  object
#  10  marital_status          23492 non-null  object
#  11  Level of Educuation     23495 non-null  object
#  12  Type of Job             23494 non-null  object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 2.3+ MB

# %%
df.columns
# Out:
# Index(['country', 'year', 'uniqueid', 'Has a Bank account', 'Type of Location',
#        'Cell Phone Access', 'household_size', 'Respondent Age',
#        'gender_of_respondent', 'The relathip with head', 'marital_status',
#        'Level of Educuation', 'Type of Job'],
#       dtype='object')

# %%
df.dtypes
# Out:
# country                    object
# year                        int64
# uniqueid                   object
# Has a Bank account         object
# Type of Location           object
# Cell Phone Access          object
# household_size            float64
# Respondent Age            float64
# gender_of_respondent       object
# The relathip with head     object
# marital_status             object
# Level of Educuation        object
# Type of Job                object
# dtype: object

# %%
df.describe()
# Out:
#                year  household_size  Respondent Age
# count  23524.000000    23496.000000    23490.000000
# mean    2016.979000        3.681818       38.804300
# std        0.899669        2.279933       16.519996
# min     2016.000000        0.000000       16.000000
# 25%     2016.000000        2.000000       26.000000
# 50%     2017.000000        3.000000       35.000000
# 75%     2018.000000        5.000000       49.000000
# max     2056.000000       21.000000      100.000000

# %% [markdown]
# ***Data Preperation***

# %%
## Droping irrelevant columns and rows

# %%
df.head()
# Out:
#   country  year    uniqueid Has a Bank account Type of Location  \
# 0   Kenya  2018  uniqueid_1                Yes            Rural
# 1   Kenya  2018  uniqueid_2                 No            Rural
# 2   Kenya  2018  uniqueid_3                Yes            Urban
# 3   Kenya  2018  uniqueid_4                 No            Rural
# 4   Kenya  2018  uniqueid_5                 No            Urban
#
#   Cell Phone Access  household_size  Respondent Age gender_of_respondent  \
# 0               Yes             3.0            24.0               Female
# 1                No             5.0            70.0               Female
# 2               Yes             5.0            26.0                 Male
# 3               Yes             5.0            34.0               Female
# 4                No             8.0            26.0                 Male
#
#   The relathip with head           marital_status  \
# 0                 Spouse  Married/Living together
# ...

# %%
# example of droping columns
df.drop(['marital_status'],axis=1)
# Out:
#       country  year       uniqueid Has a Bank account Type of Location  \
# 0       Kenya  2018     uniqueid_1                Yes            Rural
# 1       Kenya  2018     uniqueid_2                 No            Rural
# 2       Kenya  2018     uniqueid_3                Yes            Urban
# 3       Kenya  2018     uniqueid_4                 No            Rural
# 4       Kenya  2018     uniqueid_5                 No            Urban
# ...       ...   ...            ...                ...              ...
# 23519  Uganda  2018  uniqueid_2113                 No            Rural
# 23520  Uganda  2018  uniqueid_2114                 No            Rural
# 23521  Uganda  2018  uniqueid_2115                 No            Rural
# 23522  Uganda  2018  uniqueid_2116                 No            Urban
# 23523  Uganda  2018  uniqueid_2117                 No            Rural
#
#       Cell Phone Access  household_size  Respondent Age gender_of_respondent  \
# ...

# %%
df['year']=pd.to_datetime(df['year'])

# %%
df
# Out:
#       country                          year       uniqueid Has a Bank account  \
# 0       Kenya 1970-01-01 00:00:00.000002018     uniqueid_1                Yes
# 1       Kenya 1970-01-01 00:00:00.000002018     uniqueid_2                 No
# 2       Kenya 1970-01-01 00:00:00.000002018     uniqueid_3                Yes
# 3       Kenya 1970-01-01 00:00:00.000002018     uniqueid_4                 No
# 4       Kenya 1970-01-01 00:00:00.000002018     uniqueid_5                 No
# ...       ...                           ...            ...                ...
# 23519  Uganda 1970-01-01 00:00:00.000002018  uniqueid_2113                 No
# 23520  Uganda 1970-01-01 00:00:00.000002018  uniqueid_2114                 No
# 23521  Uganda 1970-01-01 00:00:00.000002018  uniqueid_2115                 No
# 23522  Uganda 1970-01-01 00:00:00.000002018  uniqueid_2116                 No
# 23523  Uganda 1970-01-01 00:00:00.000002018  uniqueid_2117                 No
#
# ...

# %%
# Rename columns
df.rename(columns={'country':'Country_Name',
                  'year':'Year',
                  'uniqueid':'Uniqueid',
                  'Has a Bank account':'Has_a_Bank_account',
                  'household_size':'Household_size',
                  'gender_of_respondent':'Gender_of_respondent',
                  'marital_status':'Marital_status',
                  })
# Out:
#       Country_Name                          Year       Uniqueid  \
# 0            Kenya 1970-01-01 00:00:00.000002018     uniqueid_1
# 1            Kenya 1970-01-01 00:00:00.000002018     uniqueid_2
# 2            Kenya 1970-01-01 00:00:00.000002018     uniqueid_3
# 3            Kenya 1970-01-01 00:00:00.000002018     uniqueid_4
# 4            Kenya 1970-01-01 00:00:00.000002018     uniqueid_5
# ...            ...                           ...            ...
# 23519       Uganda 1970-01-01 00:00:00.000002018  uniqueid_2113
# 23520       Uganda 1970-01-01 00:00:00.000002018  uniqueid_2114
# 23521       Uganda 1970-01-01 00:00:00.000002018  uniqueid_2115
# 23522       Uganda 1970-01-01 00:00:00.000002018  uniqueid_2116
# 23523       Uganda 1970-01-01 00:00:00.000002018  uniqueid_2117
#
#       Has_a_Bank_account Type of Location Cell Phone Access  Household_size  \
# 0                    Yes            Rural               Yes             3.0
# ...

# %%
# how many miss and NUN value per column
df.isna().sum()
# Out:
# Country_Name              14
# Year                       0
# Uniqueid                   0
# Has_a_Bank_account        36
# Type of Location          15
# Cell Phone Access         11
# Household_size            28
# Respondent Age            34
# Gender_of_respondent      34
# The relathip with head     4
# Marital_status            32
# Level of Educuation       29
# Type of Job               30
# dtype: int64

# %%
# find duplicate values
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 23519    False
# 23520    False
# 23521    False
# 23522    False
# 23523    False
# Length: 23524, dtype: bool

# %%
# where is the duplicate value in column 
df.loc[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Country_Name, Year, Uniqueid, Has_a_Bank_account, Type of Location, Cell Phone Access, Household_size, Respondent Age, Gender_of_respondent, The relathip with head, Marital_status, Level of Educuation, Type of Job]
# Index: []

# %%
#Checking for duplicate 'Has_a_Bank_account'
df.loc[df.duplicated(subset=['Country_Name'])].head(5)
# Out:
#   Country_Name                          Year    Uniqueid Has_a_Bank_account  \
# 1        Kenya 1970-01-01 00:00:00.000002018  uniqueid_2                 No
# 2        Kenya 1970-01-01 00:00:00.000002018  uniqueid_3                Yes
# 3        Kenya 1970-01-01 00:00:00.000002018  uniqueid_4                 No
# 4        Kenya 1970-01-01 00:00:00.000002018  uniqueid_5                 No
# 5        Kenya 1970-01-01 00:00:00.000002018  uniqueid_6                 No
#
#   Type of Location Cell Phone Access  Household_size  Respondent Age  \
# 1            Rural                No             5.0            70.0
# 2            Urban               Yes             5.0            26.0
# 3            Rural               Yes             5.0            34.0
# 4            Urban                No             8.0            26.0
# 5            Rural                No             7.0            26.0
#
#   Gender_of_respondent The relathip with head           Marital_status  \
# ...

# %%
# Checking an example duplicate
df.query('Country_Name=="Kenya"')
# Out:
#      Country_Name                          Year       Uniqueid  \
# 0           Kenya 1970-01-01 00:00:00.000002018     uniqueid_1
# 1           Kenya 1970-01-01 00:00:00.000002018     uniqueid_2
# 2           Kenya 1970-01-01 00:00:00.000002018     uniqueid_3
# 3           Kenya 1970-01-01 00:00:00.000002018     uniqueid_4
# 4           Kenya 1970-01-01 00:00:00.000002018     uniqueid_5
# ...           ...                           ...            ...
# 6063        Kenya 1970-01-01 00:00:00.000002018  uniqueid_6067
# 6064        Kenya 1970-01-01 00:00:00.000002018  uniqueid_6068
# 6065        Kenya 1970-01-01 00:00:00.000002018  uniqueid_6069
# 6066        Kenya 1970-01-01 00:00:00.000002018  uniqueid_6070
# 6067        Kenya 1970-01-01 00:00:00.000002018  uniqueid_6071
#
#      Has_a_Bank_account Type of Location Cell Phone Access  Household_size  \
# 0                   Yes            Rural               Yes             3.0
# ...

# %%
df.columns
# Out:
# Index(['Country_Name', 'Year', 'Uniqueid', 'Has_a_Bank_account',
#        'Type of Location', 'Cell Phone Access', 'Household_size',
#        'Respondent Age', 'Gender_of_respondent', 'The relathip with head',
#        'Marital_status', 'Level of Educuation', 'Type of Job'],
#       dtype='object')

# %%
df.loc[~df.duplicated(subset=['Country_Name','Year','Type of Location'])] \
    .reset_index(drop=True)
# Out:
#    Country_Name                          Year       Uniqueid  \
# 0         Kenya 1970-01-01 00:00:00.000002018     uniqueid_1
# 1         Kenya 1970-01-01 00:00:00.000002018     uniqueid_3
# 2         Kenya 1970-01-01 00:00:00.000002029   uniqueid_214
# 3         Kenya 1970-01-01 00:00:00.000002056   uniqueid_309
# 4        Rwanda 1970-01-01 00:00:00.000002016     uniqueid_1
# 5        Rwanda 1970-01-01 00:00:00.000002016     uniqueid_3
# 6        Rwanda 1970-01-01 00:00:00.000002039   uniqueid_947
# 7      Tanzania 1970-01-01 00:00:00.000002017     uniqueid_1
# 8      Tanzania 1970-01-01 00:00:00.000002017     uniqueid_2
# 9      Tanzania 1970-01-01 00:00:00.000002017  uniqueid_1625
# 10          NaN 1970-01-01 00:00:00.000002017  uniqueid_3398
# 11          NaN 1970-01-01 00:00:00.000002017  uniqueid_3403
# 12       Uganda 1970-01-01 00:00:00.000002018     uniqueid_1
# 13       Uganda 1970-01-01 00:00:00.000002018     uniqueid_2
#
# ...

# %%
df.shape
# Out:
# (23524, 13)

# %% [markdown]
# ***Feature Understanding***

# %%
#Ploting Feature Distributions

# %%
df['Year'].value_counts()
# Out:
# Year
# 1970-01-01 00:00:00.000002016    8734
# 1970-01-01 00:00:00.000002018    8167
# 1970-01-01 00:00:00.000002017    6620
# 1970-01-01 00:00:00.000002029       1
# 1970-01-01 00:00:00.000002056       1
# 1970-01-01 00:00:00.000002039       1
# Name: count, dtype: int64

# %%
ax=df['Year'].value_counts()\
    .head(10)\
    .plot(kind='bar',title='Top years')
ax.set_xlabel('Years')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
df
# Out:
#       Country_Name                          Year       Uniqueid  \
# 0            Kenya 1970-01-01 00:00:00.000002018     uniqueid_1
# 1            Kenya 1970-01-01 00:00:00.000002018     uniqueid_2
# 2            Kenya 1970-01-01 00:00:00.000002018     uniqueid_3
# 3            Kenya 1970-01-01 00:00:00.000002018     uniqueid_4
# 4            Kenya 1970-01-01 00:00:00.000002018     uniqueid_5
# ...            ...                           ...            ...
# 23519       Uganda 1970-01-01 00:00:00.000002018  uniqueid_2113
# 23520       Uganda 1970-01-01 00:00:00.000002018  uniqueid_2114
# 23521       Uganda 1970-01-01 00:00:00.000002018  uniqueid_2115
# 23522       Uganda 1970-01-01 00:00:00.000002018  uniqueid_2116
# 23523       Uganda 1970-01-01 00:00:00.000002018  uniqueid_2117
#
#       Has_a_Bank_account Type of Location Cell Phone Access  Household_size  \
# 0                    Yes            Rural               Yes             3.0
# ...

# %%
df['Respondent Age'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
ax=df['Respondent Age'].plot(kind='hist',
                         bins=20,
                         title='Respondent Age')
ax.set_xlabel("age")
# Out:
# Text(0.5, 0, 'age')

# %%
ax=df['Respondent Age'].plot(kind='kde',
                         title='Respondent Age')
ax.set_xlabel("age")
# Out:
# Text(0.5, 0, 'age')

# %% [markdown]
# ***Feature Relationships***

# %%
#Scatter plot
df.plot(kind='scatter',x='Respondent Age',y='Household_size')
# Out:
# <Axes: xlabel='Respondent Age', ylabel='Household_size'>
